# %% [markdown]
# # This notebook is meant as a tool to monitor the training process

# %%
import os,sys
currentdir = os.getcwd()
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from utils import plot_utils

# %%
from IPython import display
import time

# %%
# %matplotlib inline

# %% [markdown]
# You will need to change the location of where these files are

# %%
#loc="../model_state_dumps/20191221_165701" # resnet 50 training bug 3 channels 25 epochs
#loc="../model_state_dumps/20191222_061615/" #resnet 50 corrected bug
#loc="../model_state_dumps/20191222_142010/" #resnet 50 slow training
loc="../model_state_dumps/20191223_095927/" #resnet 50 half learning rate (0.0005) cluster energy scaling

# %%
iter_lim=30
iter=0
while iter<iter_lim:
    try:
        #for unsmoothed plot
        #fig=plot_utils.disp_learn_hist(loc,losslim=3.0,show=False)
        fig=plot_utils.disp_learn_hist_smoothed(loc,window_train=10,window_val=1,losslim=0.5,show=False)
        display.display(fig)
        display.clear_output(wait=True,)
        time.sleep(10)
        iter+=1
    except KeyboardInterrupt:
        break
